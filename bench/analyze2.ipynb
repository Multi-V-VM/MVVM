# %%
raw_data = """
bfs-pure.aot -g20 -n30
Execution time: 12.66451 s
bfs-stack.aot -g20 -n30
Execution time: 19.363419 s
bfs-ckpt.aot -g20 -n30
Execution time: 25.575047 s
bfs-ckpt-restore.aot -g20 -n30
Execution time: 24.420928 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 34.184565 s
bfs-ckpt-restore-br.aot -g20 -n30
Execution time: 50.532033 s
bfs-pure.aot -u20 -n30
Execution time: 7.892358 s
bfs-stack.aot -u20 -n30
Execution time: 11.44812 s
bfs-ckpt.aot -u20 -n30
Execution time: 15.724017 s
bfs-ckpt-restore.aot -u20 -n30
Execution time: 15.339396 s
bfs-ckpt-br.aot -u20 -n30
Execution time: 19.942437 s
bfs-ckpt-restore-br.aot -u20 -n30
Execution time: 31.024578 s
bc-pure.aot -g20 -vn30
Execution time: 52.434616 s
bc-stack.aot -g20 -vn30
Execution time: 49.442141 s
bc-ckpt.aot -g20 -vn30
Execution time: 59.591216 s
bc-ckpt-restore.aot -g20 -vn30
Execution time: 64.911727 s
bc-ckpt-br.aot -g20 -vn30
Execution time: 110.127361 s
bc-ckpt-restore-br.aot -g20 -vn30
Execution time: 171.664958 s
bfs-pure.aot -g20 -vn30
Execution time: 18.7795 s
bfs-stack.aot -g20 -vn30
Execution time: 22.624093 s
bfs-ckpt.aot -g20 -vn30
Execution time: 31.618931 s
bfs-ckpt-restore.aot -g20 -vn30
Execution time: 46.049326 s
bfs-ckpt-br.aot -g20 -vn30
Execution time: 52.16663 s
bfs-ckpt-restore-br.aot -g20 -vn30
Execution time: 78.645178 s
cc-pure.aot -g20 -vn30
Execution time: 24.349211 s
cc-stack.aot -g20 -vn30
Execution time: 29.484668 s
cc-ckpt.aot -g20 -vn30
Execution time: 37.81981 s
cc-ckpt-restore.aot -g20 -vn30
Execution time: 44.411803 s
cc-ckpt-br.aot -g20 -vn30
Execution time: 73.093745 s
cc-ckpt-restore-br.aot -g20 -vn30
Execution time: 80.06 s
cc_sv-pure.aot -g20 -vn30
Execution time: 38.942158 s
cc_sv-stack.aot -g20 -vn30
Execution time: 47.595682 s
cc_sv-ckpt.aot -g20 -vn30
Execution time: 47.475548 s
cc_sv-ckpt-restore.aot -g20 -vn30
Execution time: 65.902676 s
cc_sv-ckpt-br.aot -g20 -vn30
Execution time: 104.210196 s
cc_sv-ckpt-restore-br.aot -g20 -vn30
Execution time: 110.050996 s
pr-pure.aot -g20 -vn30
Execution time: 42.646877 s
pr-stack.aot -g20 -vn30
Execution time: 45.513463 s
pr-ckpt.aot -g20 -vn30
Execution time: 51.302999 s
pr-ckpt-restore.aot -g20 -vn30
Execution time: 55.920102 s
pr-ckpt-br.aot -g20 -vn30
Execution time: 114.182758 s
pr-ckpt-restore-br.aot -g20 -vn30
Execution time: 123.280192 s
pr_spmv-pure.aot -g20 -vn30
Execution time: 42.546045 s
pr_spmv-stack.aot -g20 -vn30
Execution time: 43.792622 s
pr_spmv-ckpt.aot -g20 -vn30
Execution time: 53.402771 s
pr_spmv-ckpt-restore.aot -g20 -vn30
Execution time: 51.554446 s
pr_spmv-ckpt-br.aot -g20 -vn30
Execution time: 105.826534 s
pr_spmv-ckpt-restore-br.aot -g20 -vn30
Execution time: 116.04941 s
sssp-pure.aot -g20 -vn30
Execution time: 44.316647 s
sssp-stack.aot -g20 -vn30
Execution time: 43.177305 s
sssp-ckpt.aot -g20 -vn30
Execution time: 45.723092 s
sssp-ckpt-restore.aot -g20 -vn30
Execution time: 44.764019 s
sssp-ckpt-br.aot -g20 -vn30
Execution time: 100.650863 s
sssp-ckpt-restore-br.aot -g20 -vn30
Execution time: 178.1836 s
tc-pure.aot -g20 -n2
Execution time: 56.479342 s
tc-stack.aot -g20 -n2
Execution time: 60.72293 s
tc-ckpt.aot -g20 -n2
Execution time: 77.421323 s
tc-ckpt-restore.aot -g20 -n2
Execution time: 78.003302 s
tc-ckpt-br.aot -g20 -n2
Execution time: 151.69701 s
tc-ckpt-restore-br.aot -g20 -n2
Execution time: 330.625153 s
linpack-pure.aot
Execution time: 49.190472 s
linpack-stack.aot
Execution time: 48.749151 s
linpack-ckpt.aot
Execution time: 48.620698 s
linpack-ckpt-restore.aot
Execution time: 49.4503 s
linpack-ckpt-br.aot
Execution time: 177.647345 s
linpack-ckpt-restore-br.aot
Execution time: 188.133851 s
llama-pure.aot stories110M.bin
Execution time: 43.642507 s
llama-stack.aot stories110M.bin
Execution time: 42.407306 s
llama-ckpt.aot stories110M.bin
Execution time: 42.53966 s
llama-ckpt-restore.aot stories110M.bin
Execution time: 43.549729 s
llama-ckpt-br.aot stories110M.bin
Execution time: 101.298057 s
llama-ckpt-restore-br.aot stories110M.bin
Execution time: 101.288088 
"""

p = []

lines = raw_data.split('\n')
for line in lines:
    if line == '':
        continue
    if line.startswith('Execution time'):
        time = line.split(' ')[2]
        p.append(time)
    else:
        aot = line.split(' ')[0].strip()
        program = aot.split('.')[0].split('-')[0].strip()
        arg = " ".join(line.split(' ')[1:]).strip()
        # print(aot, program, arg)
        
        if "ckpt.aot" in aot:
            variant = "ckpt"
        elif "pure.aot" in aot:
            variant = "pure"
        elif "stack.aot" in aot:
            variant = "stack"
        elif "ckpt-restore.aot" in aot:
            variant = "ckpt-restore"
        elif "ckpt-br.aot" in aot:
            variant = "ckpt-br"
        elif "ckpt-restore-br.aot" in aot:
            variant = "ckpt-restore-br"
        else:
            assert 0

        p.append((program, variant, arg))

data = {}
for i in range(len(p)):
    if i % 2 == 1:
        continue
    program, variant, arg = p[i]
    time = float(p[i+1])
    test = program + " " + arg
    if test not in data:
        data[test] = {}
    data[test][variant] = time

delta_data = {}
for k, v in data.items():
    pure = v["pure"]
    stack = v["stack"]
    ckpt = v["ckpt"]
    ckpt_restore = v["ckpt-restore"]
    ckpt_br = v["ckpt-br"]
    ckpt_restore_br = v["ckpt-restore-br"]

    stack = max(stack, pure)
    ckpt = max(ckpt, stack)
    ckpt_restore = max(ckpt_restore, ckpt)
    ckpt_br = max(ckpt_br, ckpt)
    ckpt_restore_br = max(ckpt_restore_br, ckpt_restore)

    assert pure <= stack
    assert stack <= ckpt
    assert ckpt <= ckpt_restore
    delta_data[k] = {
        "aot": pure,
        "stack": stack - pure,
        "ckpt": ckpt - stack,
        "ckpt-restore": ckpt_restore - ckpt,
        "ckpt-br": ckpt_br - ckpt_restore,
        "ckpt-restore-br": ckpt_restore_br - ckpt_br,
    }

# %%
len(delta_data)
# Out:
# 12

# %%
# calculate average time of ckpt
aot_time = 0
stack_time = 0
ckpt_time = 0
ckpt_restore_time = 0
ckpt_br_time = 0
ckpt_restore_br_time = 0
for k, v in data.items():
    aot_time += v["pure"]
    stack_time += v["stack"]
    ckpt_time += v["ckpt"]
    ckpt_restore_time += v["ckpt-restore"]
    ckpt_br_time += v["ckpt-br"]
    ckpt_restore_br_time += v["ckpt-restore-br"]
aot_time /= len(data)
stack_time /= len(data)
ckpt_time /= len(data)
ckpt_restore_time /= len(data)
ckpt_br_time /= len(data)
ckpt_restore_br_time /= len(data)
print("average time of aot:", aot_time)
print("average time of ckpt:", ckpt_time)
print("average time of ckpt-restore:", ckpt_restore_time)
print("average time of ckpt-br:", ckpt_br_time)
print("average time of ckpt-restore-br:", ckpt_restore_br_time)
print("stack/aot", stack_time / aot_time)
print("ckpt/aot", ckpt_time / aot_time)
print("ckpt-restore/aot", ckpt_restore_time / aot_time)
print("ckpt-br/aot", ckpt_br_time / aot_time)
print("ckpt-restore-br/aot", ckpt_restore_br_time / aot_time)
# Out:
# average time of aot: 36.157020249999995
# average time of ckpt: 44.734592666666664
# average time of ckpt-restore: 48.68981283333333
# average time of ckpt-br: 95.41895841666667
# average time of ckpt-restore-br: 129.96150308333333
# stack/aot 1.07014925637666
# ckpt/aot 1.2372311755050298
# ckpt-restore/aot 1.34662127843163
# ckpt-br/aot 2.6390160958207467
# ckpt-restore-br/aot 3.594364308362312

# %%
import matplotlib.pyplot as plt
import numpy as np

keys = []
weights = {
    "aot": [],
    "stack": [],
    "ckpt": [],
    "ckpt-restore": [],
    "ckpt-br": [],
    "ckpt-restore-br": [],
}
for k, v in delta_data.items():
    keys.append(k)
    for w in weights:
        weights[w].append(v[w])
width = 0.5

fig, ax = plt.subplots(figsize=(20, 10))
bottom = np.zeros(len(keys))

for boolean, weight_count in weights.items():
    p = ax.bar(keys, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

ax.set_title("Performance")
# add note at aot
for i in range(len(keys)):
    ax.text(i, 0, "{:.2f}".format(weights["aot"][i]), ha='center', va='bottom')
# add note at stack
for i in range(len(keys)):
    ax.text(i, weights["aot"][i], "{:.2f}".format(weights["stack"][i]), ha='center', va='bottom')
# add note at ckpt
for i in range(len(keys)):
    ax.text(i, weights["aot"][i] + weights["stack"][i], "{:.2f}".format(weights["ckpt"][i]), ha='center', va='bottom')
# add note at ckpt-restore
for i in range(len(keys)):
    ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i], "{:.2f}".format(weights["ckpt-restore"][i]), ha='center', va='bottom')
# add note at ckpt-br
for i in range(len(keys)):
    ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i] + weights["ckpt-restore"][i], "{:.2f}".format(weights["ckpt-br"][i]), ha='center', va='bottom')
# add note at ckpt-restore-br
for i in range(len(keys)):
    ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i] + weights["ckpt-restore"][i] + weights["ckpt-br"][i], "{:.2f}".format(weights["ckpt-restore-br"][i]), ha='center', va='bottom')
# add note at total
# for i in range(len(keys)):
#     ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i] + weights["ckpt-restore"][i] + weights["ckpt-br"][i] + weights["ckpt-restore-br"][i], "{:.2f}".format(sum(weights.values())), ha='center', va='bottom')
# add text at upper left
ax.legend(loc="upper right")
# plt.show()
plt.savefig("performance.png", dpi=300)

# %%
# import matplotlib.pyplot as plt

# # draw pie chart for each test, show in one figure
# fig, axs = plt.subplots(4, 3, figsize=(15, 15))
# fig.tight_layout(pad=3.0)
# fig.suptitle('Execution time of each variant for each test')
# for i, (k, v) in enumerate(delta_data.items()):
#     row = i // 3
#     col = i % 3
#     print(row, col)
#     axs[row, col].pie(v.values(), labels=v.keys(), autopct='%1.1f%%')
#     axs[row, col].set_title(k)
# # save figure
# plt.savefig('pie.png', dpi=300)

# %%
# import matplotlib.pyplot as plt

# # draw pie chart for each test, show in one figure
# fig, axs = plt.subplots(4, 3, figsize=(15, 15))
# fig.tight_layout(pad=3.0)
# fig.suptitle('Execution time of each variant for each test')
# for i, (k, v) in enumerate(delta_data.items()):
#     v.pop("ckpt-br")
#     row = i // 3
#     col = i % 3
#     print(row, col)
#     axs[row, col].pie(v.values(), labels=v.keys(), autopct='%1.1f%%')
#     axs[row, col].set_title(k)
# # save figure
# plt.savefig('pie-without-ckpt-br.png', dpi=300)
