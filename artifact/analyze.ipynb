# %%
raw_data = """
a=b redis.aot
Execution time: 55.200559 s
a=b redis-pure.aot
Execution time: 9.941405 s
a=b redis-stack.aot
Execution time: 10.309126 s
a=b redis-ckpt.aot
Execution time: 19.143253 s
a=b redis-ckpt-br.aot
Execution time: 57.495521 s
LINPACK_ARRAY_SIZE=600 linpack-pure.aot
Execution time: 27.321932 s
LINPACK_ARRAY_SIZE=600 linpack-stack.aot
Execution time: 26.479506 s
LINPACK_ARRAY_SIZE=600 linpack-ckpt.aot
Execution time: 25.479506 s
LINPACK_ARRAY_SIZE=600 linpack-ckpt-br.aot
Execution time: 23.515278 s
bfs.aot -g20 -n30
Execution time: 40.48514 s
bfs-pure.aot -g20 -n30
Execution time: 12.891097 s
bfs-stack.aot -g20 -n30
Execution time: 29.704944 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.489558 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.880147 s
bfs.aot -u20 -n30
Execution time: 23.355268 s
bfs-pure.aot -u20 -n30
Execution time: 7.68988 s
bfs-stack.aot -u20 -n30
Execution time: 17.232749 s
bfs-ckpt.aot -u20 -n30
Execution time: 19.834203 s
bfs-ckpt-br.aot -u20 -n30
Execution time: 39.5976 s
bfs.aot -g20 -n30
Execution time: 40.082361 s
bfs-pure.aot -g20 -n30
Execution time: 12.812154 s
bfs-stack.aot -g20 -n30
Execution time: 29.138806 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.214198 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.743197 s
bfs.aot -g20 -n30
Execution time: 40.394383 s
bfs-pure.aot -g20 -n30
Execution time: 12.702718 s
bfs-stack.aot -g20 -n30
Execution time: 29.183152 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.579476 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.678704 s
bfs.aot -g20 -n30
Execution time: 40.44207 s
bfs-pure.aot -g20 -n30
Execution time: 13.011162 s
bfs-stack.aot -g20 -n30
Execution time: 29.292811 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.349887 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.722782 s
bfs.aot -g20 -n30
Execution time: 40.359308 s
bfs-pure.aot -g20 -n30
Execution time: 13.040106 s
bfs-stack.aot -g20 -n30
Execution time: 29.163994 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.16543 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.685541 s
bfs.aot -g20 -n30
Execution time: 40.116333 s
bfs-pure.aot -g20 -n30
Execution time: 12.812886 s
bfs-stack.aot -g20 -n30
Execution time: 29.203627 s
bfs-ckpt.aot -g20 -n30
Execution time: 39.968658 s
bfs-ckpt-br.aot -g20 -n30
Execution time: 73.603797 s
bfs.aot -g20 -n30
Execution time: 40.521269 s
bfs-pure.aot -g20 -n30
Execution time: 12.885636 s
bfs-stack.aot -g20 -n30
Execution time: 29.216374 s
bfs-ckpt.aot -g20 -n30
Execution time: 40.444212 s
bfs-ckpt-br.aot -g20 -n30
Execution time:
Execution time: 35.1234125 s
OMP_NUM_THREADS=2 llama-ckpt-br.aot stories15M.bin
Execution time: 30.1134125 s
"""

p = []

lines = raw_data.split('\n')
for line in lines:
    if line == '':
        continue
    if line.startswith('Execution time'):
        time = line.split(' ')[2]
        p.append(time)
    else:
        env = line.split(' ')[0]
        aot = line.split(' ')[1]
        program = aot.split('.')[0].split('-')[0]
        arg = " ".join(line.split(' ')[2:])
        # print(aot, program, arg)
        
        if "ckpt.aot" in aot:
            variant = "ckpt"
        elif "pure.aot" in aot:
            variant = "pure"
        elif "stack.aot" in aot:
            variant = "stack"
        elif "ckpt-br.aot" in aot:
            variant = "ckpt-br"
        else:
            variant = "aot"
        
        p.append((env, program, variant, arg))
print(p)
data = {}
for i in range(len(p)):
    if i % 2 == 1:
        continue
    print(i)
    env, program, variant, arg = p[i]
    if variant == "aot":
        continue
    time = float(p[i+1])
    test = program + " " + arg
    if test not in data:
        data[test] = {}
    data[test][variant] = time

delta_data = {}
for k, v in data.items():
    pure = v["pure"]
    stack = v["stack"]
    ckpt = v["ckpt"]
    ckpt_br = v["ckpt-br"]

    stack = max(stack, pure)
    ckpt = max(ckpt, stack)
    ckpt_br = max(ckpt_br, ckpt)
    delta_data[k] = {
        "aot": pure,
        "stack": stack - pure,
        "ckpt": ckpt - stack,
        "ckpt-br": ckpt_br - ckpt
    }
# Out:
# [('a=b', 'redis', 'aot', ''), '55.200559', ('a=b', 'redis', 'pure', ''), '9.941405', ('a=b', 'redis', 'stack', ''), '10.309126', ('a=b', 'redis', 'ckpt', ''), '19.143253', ('a=b', 'redis', 'ckpt-br', ''), '57.495521', ('LINPACK_ARRAY_SIZE=600', 'linpack', 'pure', ''), '27.321932', ('LINPACK_ARRAY_SIZE=600', 'linpack', 'stack', ''), '26.479506', ('LINPACK_ARRAY_SIZE=600', 'linpack', 'ckpt', ''), '25.479506', ('LINPACK_ARRAY_SIZE=600', 'linpack', 'ckpt-br', ''), '23.515278', ('bfs.aot', '', 'aot', '-n30'), '40.48514', ('bfs-pure.aot', '', 'aot', '-n30'), '12.891097', ('bfs-stack.aot', '', 'aot', '-n30'), '29.704944', ('bfs-ckpt.aot', '', 'aot', '-n30'), '40.489558', ('bfs-ckpt-br.aot', '', 'aot', '-n30'), '73.880147', ('bfs.aot', '', 'aot', '-n30'), '23.355268', ('bfs-pure.aot', '', 'aot', '-n30'), '7.68988', ('bfs-stack.aot', '', 'aot', '-n30'), '17.232749', ('bfs-ckpt.aot', '', 'aot', '-n30'), '19.834203', ('bfs-ckpt-br.aot', '', 'aot', '-n30'), '39.5976', ('bfs.aot', '', 'aot', '-n3
# ...

# %%
len(delta_data)
# Out:
# 3

# %%
# calculate average time of ckpt
aot_time = 0
ckpt_time = 0
ckpt_br_time = 0
for k, v in data.items():
    aot_time += v["pure"]
    ckpt_time += v["ckpt"]
    ckpt_br_time += v["ckpt-br"]
aot_time /= len(data)
ckpt_time /= len(data)
ckpt_br_time /= len(data)
print("average time of aot:", aot_time)
print("average time of ckpt:", ckpt_time)
print("average time of ckpt-br:", ckpt_br_time)
print("ckpt/aot", ckpt_time / aot_time)
print("ckpt-br/aot", ckpt_br_time / aot_time)
# Out:
# average time of aot: 22.128916500000003
# average time of ckpt: 26.58205716666667
# average time of ckpt-br: 37.04140383333333
# ckpt/aot 1.2012362723076235
# ckpt-br/aot 1.6738914367241307

# %%
import matplotlib.pyplot as plt
import numpy as np

keys = []
weights = {
    "aot": [],
    "stack": [],
    "ckpt": [],
    "ckpt-br": []
}
for k, v in delta_data.items():
    keys.append(k)
    for w in weights:
        weights[w].append(v[w])
width = 0.5

fig, ax = plt.subplots(figsize=(20, 10))
bottom = np.zeros(len(keys))

for boolean, weight_count in weights.items():
    p = ax.bar(keys, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count


ax.set_title("Performance")
# add note at aot
# for i in range(len(keys)):

#     ax.text(i, 0, "{:.2f}".format(weights["aot"][i]), ha='center', va='bottom')
# add note at stack
# for i in range(len(keys)):
#     ax.text(i, weights["aot"][i], "{:.2f}".format(weights["stack"][i]), ha='center', va='bottom')
# add note at ckpt
# for i in range(len(keys)):
#     ax.text(i, weights["aot"][i] + weights["stack"][i], "{:.2f}".format(weights["ckpt"][i]), ha='center', va='bottom')
# add note at ckpt-br
# for i in range(len(keys)):
#     ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i], "{:.2f}".format(weights["ckpt-br"][i]), ha='center', va='bottom')
# add note at total
# for i in range(len(keys)):
#     ax.text(i, weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i] + weights["ckpt-br"][i], "total: {:.2f}".format(weights["aot"][i] + weights["stack"][i] + weights["ckpt"][i] + weights["ckpt-br"][i]), ha='center', va='bottom')
# add text at upper left
ax.legend(loc="upper right")
plt.show()

plt.savefig("performance.png", dpi=300)

# %%
# import matplotlib.pyplot as plt

# # draw pie chart for each test, show in one figure
# fig, axs = plt.subplots(4, 3, figsize=(15, 15))
# fig.tight_layout(pad=3.0)
# fig.suptitle('Execution time of each variant for each test')
# for i, (k, v) in enumerate(delta_data.items()):
#     row = i // 3
#     col = i % 3
#     print(row, col)
#     axs[row, col].pie(v.values(), labels=v.keys(), autopct='%1.1f%%')
#     axs[row, col].set_title(k)
# # save figure
# plt.savefig('pie.png', dpi=300)

# %%
# import matplotlib.pyplot as plt

# # draw pie chart for each test, show in one figure
# fig, axs = plt.subplots(4, 3, figsize=(15, 15))
# fig.tight_layout(pad=3.0)
# fig.suptitle('Execution time of each variant for each test')
# for i, (k, v) in enumerate(delta_data.items()):
#     v.pop("ckpt-br")
#     row = i // 3
#     col = i % 3
#     print(row, col)
#     axs[row, col].pie(v.values(), labels=v.keys(), autopct='%1.1f%%')
#     axs[row, col].set_title(k)
# # save figure
# plt.savefig('pie-without-ckpt-br.png', dpi=300)
